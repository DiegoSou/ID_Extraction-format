# %%
import app

# %%
ext1 = app.get_extraction(1)

# %%
ext2 = app.get_extraction(2)

# %%
ext1.head()
# Out:
#                                                query  \
# 0  Loja de moda, José Bonifácio, Sâo Paulo, São P...
# 1  Loja de moda, José Bonifácio, Sâo Paulo, São P...
# 2  Loja de moda, José Bonifácio, Sâo Paulo, São P...
# 3  Loja de moda, José Bonifácio, Sâo Paulo, São P...
# 4  Loja de moda, José Bonifácio, Sâo Paulo, São P...
#
#                              name  \
# 0                         Moda Ka
# 1                   Maroleo modas
# 2  Touchic Modas - José Bonifácio
# 3   RK Modas Feminina e Masculina
# 4  À Dondóquinha - José Bonifácio
#
#                                                 site                   type  \
# 0  https://www.facebook.com/P%C3%A1gina-Moda-Ka-J...          Loja de Roupa
# 1                                                NaN          Loja de Roupa
# 2                                                NaN          Loja de Roupa
# 3  https://instagram.com/keurifernandajb?igshid=Y...  Loja de moda feminina
# 4                                                NaN          Loja de Roupa
#
#                 subtypes               category              phone  \
# 0          Loja de Roupa          Loja de Roupa                NaN
# 1          Loja de Roupa          Loja de Roupa   +55 17 3245-1876
# 2          Loja de Roupa          Loja de Roupa  +55 17 99762-3567
# 3  Loja de moda feminina  Loja de moda feminina  +55 17 99253-7382
# 4          Loja de Roupa          Loja de Roupa  +55 17 99642-4457
#
#                                         full_address  \
# 0  Av. Nove de Julho, 601 - Centro Histórico de S...
# 1  Rua:Domingos Fernandes Alonso, 363 - Centro, J...
# 2  R. São José, 335 - Centro, José Bonifácio - SP...
# 3  Av. Antônio Gonçalves da Silva, 1017 - Centro,...
# 4  Av. Nove de Julho, 349 - Centro, José Bonifáci...
#
#                          borough                                street  ...  \
# 0  Centro Histórico de São Paulo                Av. Nove de Julho, 601  ...
# 1                         Centro    Rua:Domingos Fernandes Alonso, 363  ...
# 2                         Centro                      R. São José, 335  ...
# 3                         Centro  Av. Antônio Gonçalves da Silva, 1017  ...
# 4                         Centro                Av. Nove de Julho, 349  ...
#
#   reservation_links booking_appointment_link menu_link order_links  \
# 0               NaN                      NaN       NaN         NaN
# 1               NaN                      NaN       NaN         NaN
# 2               NaN                      NaN       NaN         NaN
# 3               NaN                      NaN       NaN         NaN
# 4               NaN                      NaN       NaN         NaN
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Moda+Ka/@-21...
# 1  https://www.google.com/maps/place/Maroleo+moda...
# 2  https://www.google.com/maps/place/Touchic+Moda...
# 3  https://www.google.com/maps/place/RK+Modas+Fem...
# 4  https://www.google.com/maps/place/%C3%80+Dond%...
#
#                       place_id                              google_id  \
# 0  ChIJ5UUHf_y_vZQRwoWchzaAsqY  0x94bdbffc7f0745e5:0xa6b28036879c85c2
# 1  ChIJ9cby5-O_vZQR-p4apJIxRD8  0x94bdbfe3e7f2c6f5:0x3f443192a41a9efa
# 2  ChIJYZa2Gfi_vZQR_4kgWDAK4Fc  0x94bdbff819b69661:0x57e00a30582089ff
# 3  ChIJjzQx1D6_vZQRYkQFmqMBw94  0x94bdbf3ed431348f:0xdec301a39a054462
# 4  ChIJMfpSOlm_vZQRKfvHuIWVcao  0x94bdbf593a52fa31:0xaa719585b8c7fb29
#
#                     cid            reviews_id located_google_id
# 0  12011804127842305474  -6434939945867246142               NaN
# 1   4558823228693978874   4558823228693978874               NaN
# 2   6332072278836152831   6332072278836152831               NaN
# 3  16051675299053913186  -2395068774655638430               NaN
# 4  12281762060379355945  -6164982013330195671               NaN
#
# [5 rows x 59 columns]

# %%
ext1.columns
# Out:
# Index(['query', 'name', 'site', 'type', 'subtypes', 'category', 'phone',
#        'full_address', 'borough', 'street', 'city', 'postal_code', 'state',
#        'us_state', 'country', 'country_code', 'latitude', 'longitude',
#        'time_zone', 'plus_code', 'area_service', 'rating', 'reviews',
#        'reviews_link', 'reviews_tags', 'reviews_per_score',
#        'reviews_per_score_1', 'reviews_per_score_2', 'reviews_per_score_3',
#        'reviews_per_score_4', 'reviews_per_score_5', 'photos_count', 'photo',
#        'street_view', 'located_in', 'working_hours',
#        'working_hours_old_format', 'other_hours', 'popular_times',
#        'business_status', 'about', 'range', 'posts', 'logo', 'description',
#        'verified', 'owner_id', 'owner_title', 'owner_link',
#        'reservation_links', 'booking_appointment_link', 'menu_link',
#        'order_links', 'location_link', 'place_id', 'google_id', 'cid',
#        'reviews_id', 'located_google_id'],
#       dtype='object')

# %%
ext1_duplicated = ext1[ext1.duplicated(['place_id'])]

# %%
ext1_duplicated
# Out:
# Empty DataFrame
# Columns: [query, name, site, type, subtypes, category, phone, full_address, borough, street, city, postal_code, state, us_state, country, country_code, latitude, longitude, time_zone, plus_code, area_service, rating, reviews, reviews_link, reviews_tags, reviews_per_score, reviews_per_score_1, reviews_per_score_2, reviews_per_score_3, reviews_per_score_4, reviews_per_score_5, photos_count, photo, street_view, located_in, working_hours, working_hours_old_format, other_hours, popular_times, business_status, about, range, posts, logo, description, verified, owner_id, owner_title, owner_link, reservation_links, booking_appointment_link, menu_link, order_links, location_link, place_id, google_id, cid, reviews_id, located_google_id]
# Index: []
#
# [0 rows x 59 columns]

# %%
ext2_duplicated = ext2[ext2.duplicated(['place_id'])]

# %%
ext2_duplicated
# Out:
# Empty DataFrame
# Columns: [query, name, site, type, subtypes, category, phone, full_address, borough, street, city, postal_code, state, us_state, country, country_code, latitude, longitude, time_zone, plus_code, area_service, rating, reviews, reviews_link, reviews_tags, reviews_per_score, reviews_per_score_1, reviews_per_score_2, reviews_per_score_3, reviews_per_score_4, reviews_per_score_5, photos_count, photo, street_view, located_in, working_hours, working_hours_old_format, other_hours, popular_times, business_status, about, range, posts, logo, description, verified, owner_id, owner_title, owner_link, reservation_links, booking_appointment_link, menu_link, order_links, location_link, place_id, google_id, cid, reviews_id, located_google_id]
# Index: []
#
# [0 rows x 59 columns]

# %%
# dropping duplicates
# result = ext1.drop_duplicates(['place_id'],keep='first') #or keep = first or last

# %%
import pandas as pd

# %%
ext_all = pd.concat([ext1, ext2])

# %%
ext_all
# Out:
#                                                    query  \
# 0      Loja de moda, José Bonifácio, Sâo Paulo, São P...
# 1      Loja de moda, José Bonifácio, Sâo Paulo, São P...
# 2      Loja de moda, José Bonifácio, Sâo Paulo, São P...
# 3      Loja de moda, José Bonifácio, Sâo Paulo, São P...
# 4      Loja de moda, José Bonifácio, Sâo Paulo, São P...
# ...                                                  ...
# 99147       Hotel, Colônia, São Paulo, São Paulo, Brasil
# 99148       Hotel, Colônia, São Paulo, São Paulo, Brasil
# 99149       Hotel, Colônia, São Paulo, São Paulo, Brasil
# 99150       Hotel, Colônia, São Paulo, São Paulo, Brasil
# 99151       Hotel, Colônia, São Paulo, São Paulo, Brasil
#
#                                  name  \
# 0                             Moda Ka
# 1                       Maroleo modas
# 2      Touchic Modas - José Bonifácio
# 3       RK Modas Feminina e Masculina
# 4      À Dondóquinha - José Bonifácio
# ...                               ...
# 99147             Hotel Real Paulista
# 99148                  Pousada Sinpra
# 99149              Hostel do Valdemar
# 99150                    Hotel Sirena
# 99151                    Pousada Olga
#
#                                                     site  \
# 0      https://www.facebook.com/P%C3%A1gina-Moda-Ka-J...
# 1                                                    NaN
# 2                                                    NaN
# 3      https://instagram.com/keurifernandajb?igshid=Y...
# 4                                                    NaN
# ...                                                  ...
# 99147               http://www.hotelrealpaulista.com.br/
# 99148            https://www.facebook.com/pousadasinpra/
# 99149        https://www.instagram.com/hosteldovaldemar/
# 99150                    https://linktr.ee/hotelsirenapg
# 99151    http://business.google.com/website/pousada-olga
#
#                         type               subtypes               category  \
# 0              Loja de Roupa          Loja de Roupa          Loja de Roupa
# 1              Loja de Roupa          Loja de Roupa          Loja de Roupa
# 2              Loja de Roupa          Loja de Roupa          Loja de Roupa
# 3      Loja de moda feminina  Loja de moda feminina  Loja de moda feminina
# 4              Loja de Roupa          Loja de Roupa          Loja de Roupa
# ...                      ...                    ...                    ...
# 99147                  Hotel                  Hotel                 hotéis
# 99148                  Hotel                  Hotel                 hotéis
# 99149                  Hotel                  Hotel                 hotéis
# 99150                  Hotel                  Hotel                 hotéis
# 99151            Cama e café            Cama e café            Cama e café
#
#                    phone                                       full_address  \
# 0                    NaN  Av. Nove de Julho, 601 - Centro Histórico de S...
# 1       +55 17 3245-1876  Rua:Domingos Fernandes Alonso, 363 - Centro, J...
# 2      +55 17 99762-3567  R. São José, 335 - Centro, José Bonifácio - SP...
# 3      +55 17 99253-7382  Av. Antônio Gonçalves da Silva, 1017 - Centro,...
# 4      +55 17 99642-4457  Av. Nove de Julho, 349 - Centro, José Bonifáci...
# ...                  ...                                                ...
# 99147   +55 11 3884-0564  Av. Bernardino de Campos - Paraíso, São Paulo ...
# 99148                NaN  Av. dos Sindicatos, 291 - Nova Mirim, Praia Gr...
# 99149   +55 13 3471-6785  R. Vinte e Três de Maio, 481 - Nova Mirim, Pra...
# 99150   +55 13 4040-4142  Av. Pres. Kennedy, 13240 - Vila Caiçara, Praia...
# 99151   +55 13 3594-8308  R. Amin Andraus, 56 - Vila Caiçara, Praia Gran...
#
#                              borough                                street  \
# 0      Centro Histórico de São Paulo                Av. Nove de Julho, 601
# 1                             Centro    Rua:Domingos Fernandes Alonso, 363
# 2                             Centro                      R. São José, 335
# 3                             Centro  Av. Antônio Gonçalves da Silva, 1017
# 4                             Centro                Av. Nove de Julho, 349
# ...                              ...                                   ...
# 99147                        Paraíso              Av. Bernardino de Campos
# 99148                     Nova Mirim               Av. dos Sindicatos, 291
# 99149                     Nova Mirim          R. Vinte e Três de Maio, 481
# 99150                   Vila Caiçara              Av. Pres. Kennedy, 13240
# 99151                   Vila Caiçara                   R. Amin Andraus, 56
#
#        ... reservation_links booking_appointment_link menu_link order_links  \
# 0      ...               NaN                      NaN       NaN         NaN
# 1      ...               NaN                      NaN       NaN         NaN
# 2      ...               NaN                      NaN       NaN         NaN
# 3      ...               NaN                      NaN       NaN         NaN
# 4      ...               NaN                      NaN       NaN         NaN
# ...    ...               ...                      ...       ...         ...
# 99147  ...               NaN                      NaN       NaN         NaN
# 99148  ...               NaN                      NaN       NaN         NaN
# 99149  ...               NaN                      NaN       NaN         NaN
# 99150  ...               NaN                      NaN       NaN         NaN
# 99151  ...               NaN                      NaN       NaN         NaN
#
#                                            location_link  \
# 0      https://www.google.com/maps/place/Moda+Ka/@-21...
# 1      https://www.google.com/maps/place/Maroleo+moda...
# 2      https://www.google.com/maps/place/Touchic+Moda...
# 3      https://www.google.com/maps/place/RK+Modas+Fem...
# 4      https://www.google.com/maps/place/%C3%80+Dond%...
# ...                                                  ...
# 99147  https://www.google.com/maps/place/Hotel+Real+P...
# 99148  https://www.google.com/maps/place/Pousada+Sinp...
# 99149  https://www.google.com/maps/place/Hostel+do+Va...
# 99150  https://www.google.com/maps/place/Hotel+Sirena...
# 99151  https://www.google.com/maps/place/Pousada+Olga...
#
#                           place_id                              google_id  \
# 0      ChIJ5UUHf_y_vZQRwoWchzaAsqY  0x94bdbffc7f0745e5:0xa6b28036879c85c2
# 1      ChIJ9cby5-O_vZQR-p4apJIxRD8  0x94bdbfe3e7f2c6f5:0x3f443192a41a9efa
# 2      ChIJYZa2Gfi_vZQR_4kgWDAK4Fc  0x94bdbff819b69661:0x57e00a30582089ff
# 3      ChIJjzQx1D6_vZQRYkQFmqMBw94  0x94bdbf3ed431348f:0xdec301a39a054462
# 4      ChIJMfpSOlm_vZQRKfvHuIWVcao  0x94bdbf593a52fa31:0xaa719585b8c7fb29
# ...                            ...                                    ...
# 99147  ChIJY_KIuI9XzpQR0b94g6FO1lk  0x94ce578fb888f263:0x59d64ea18378bfd1
# 99148  ChIJzZBtj6kfzpQR5QP2UxE_i9E  0x94ce1fa98f6d90cd:0xd18b3f1153f603e5
# 99149  ChIJbbGiiQcfzpQRZBjppxBlwgc   0x94ce1f0789a2b16d:0x7c26510a7e91864
# 99150  ChIJ7S-1jTQgzpQRio4Wkl4JJyg  0x94ce20348db52fed:0x2827095e92168e8a
# 99151  ChIJm_tGUTIgzpQRMhmH9RKi6iE  0x94ce20325146fb9b:0x21eaa212f5871932
#
#                         cid            reviews_id located_google_id
# 0      12011804127842305474  -6434939945867246142               NaN
# 1       4558823228693978874   4558823228693978874               NaN
# 2       6332072278836152831   6332072278836152831               NaN
# 3      16051675299053913186  -2395068774655638430               NaN
# 4      12281762060379355945  -6164982013330195671               NaN
# ...                     ...                   ...               ...
# 99147   6473447969994096593   6473447969994096593               NaN
# 99148  15099231519345345509  -3347512554364206107               NaN
# 99149    559120425958316132    559120425958316132               NaN
# 99150   2893291587391360650   2893291587391360650               NaN
# 99151   2443943950114298162   2443943950114298162               NaN
#
# [213216 rows x 59 columns]

# %%
ext_result = ext_all.drop_duplicates(['place_id'],keep='first')

# %%
# ext_result.to_excel('resultado1-2-extracao03-saopaulo.xlsx')

# %%
######################## Glossário de Tipos

# %%
from pandas import DataFrame, read_csv, read_excel, merge, isnull, notnull, isna

# %%
gloss_tipos = read_csv("glossario_de_tipos.csv")

# %%
df = read_excel("modificado/extracao03-betim-mg.xlsx")

# %%
gloss_tipos.rename(columns={'Type': 'type', 'Categoria' : 'category'}, inplace=True)

# %%
gloss_tipos.index = gloss_tipos['type']

# %%
gloss_tipos
# Out:
#                                                                       type  \
# type
# Barbearia                                                        Barbearia
# Cartório de Registro Civil                      Cartório de Registro Civil
# Casa de campo                                                Casa de campo
# Centro comercial                                          Centro comercial
# Centro de saúde e beleza                          Centro de saúde e beleza
# ...                                                                    ...
# Casa de leilões                                            Casa de leilões
# Empresa de Rastreamento por Satélite  Empresa de Rastreamento por Satélite
# Alojamento independente                            Alojamento independente
# Flat                                                                  Flat
# Creche                                                              Creche
#
#                                                 category
# type
# Barbearia                               Salões de Beleza
# Cartório de Registro Civil            Serviços Jurídicos
# Casa de campo                                  Hotelaria
# Centro comercial                             Condomínios
# Centro de saúde e beleza                Salões de Beleza
# ...                                                  ...
# Casa de leilões                           Lojas em Geral
# Empresa de Rastreamento por Satélite      Lojas em Geral
# Alojamento independente                      Condomínios
# Flat                                         Condomínios
# Creche                                    Lojas em Geral
#
# [1149 rows x 2 columns]

# %%
del gloss_tipos['type']

# %%
gloss_tipos.loc['Comércio de Pneu']
# Out:
# category    Oficinas Mecânicas
# Name: Comércio de Pneu, dtype: object

# %%
df
# Out:
#        Unnamed: 0                                              query  \
# 0               0  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 1               1  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 2               2  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 3               3  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 4               4  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# ...           ...                                                ...
# 24813       24813  Lanchonetes, Vale do Jatobá, Betim, Minas Gera...
# 24814       24814  Lanchonetes, Vale do Jatobá, Betim, Minas Gera...
# 24815       24815  Lanchonetes, Vale do Jatobá, Betim, Minas Gera...
# 24816       24816  Lanchonetes, Vale do Jatobá, Betim, Minas Gera...
# 24817       24817  Lanchonetes, Granja Verde, Betim, Minas Gerais...
#
#                                         name  \
# 0                 Pneus e borracharia amorim
# 1      Borracharia Pitstop (serviço e geral)
# 2                       Borracharia Salmo 27
# 3                             Borracharia Th
# 4                      Borracharia Vida Nova
# ...                                      ...
# 24813                             RM LANCHES
# 24814                       Hot Dog da Paula
# 24815                          Delci lanches
# 24816  Lanchonete E sorveteria Souza Santana
# 24817           Dk Burguer Açaí E Sanduíches
#
#                                                     site  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 24813  https://rmlanches.negocio.site/?utm_source=gmb...
# 24814                                                NaN
# 24815                                                NaN
# 24816                                                NaN
# 24817                                                NaN
#
#                                      type                            subtypes  \
# 0      Fornecedor de produtos de borracha  Fornecedor de produtos de borracha
# 1                        Comércio de Pneu                    Comércio de Pneu
# 2                       Loja de autopeças                   Loja de autopeças
# 3                        Comércio de Pneu                    Comércio de Pneu
# 4                    Loja de pneus usados                Loja de pneus usados
# ...                                   ...                                 ...
# 24813                          Lanchonete                          Lanchonete
# 24814                          Lanchonete                          Lanchonete
# 24815                          Lanchonete                          Lanchonete
# 24816                          Lanchonete              Lanchonete, Sorveteria
# 24817                         Restaurante                         Restaurante
#
#                                category_x              phone  \
# 0      Fornecedor de produtos de borracha  +55 31 99262-7295
# 1                        Comércio de Pneu                NaN
# 2                       Loja de autopeças                NaN
# 3                        Comércio de Pneu                NaN
# 4                    Loja de pneus usados   +55 31 3597-0515
# ...                                   ...                ...
# 24813                          Lanchonete  +55 31 98912-8367
# 24814                          Lanchonete  +55 31 99177-3749
# 24815                          Lanchonete   +55 31 3533-6571
# 24816                          Lanchonete   +55 31 3533-7985
# 24817                        restaurantes                NaN
#
#                                             full_address  \
# 0      Rod. Br 381 Fernao Dias, 153 - Santa Cruz, Bet...
# 1                      Santa Cruz, Betim - MG, 32667-380
# 2      Av. Rio Madeira, 2082 - Santa Cruz, Betim - MG...
# 3      Av. das Palmeiras, 341 - Duque de Caxias, Beti...
# 4      R. Gracyra Resse de Gouvêia, 998 - Dom I. Jard...
# ...                                                  ...
# 24813  R. Coletora, 545A - Vila Pinho Vale do Jatobá,...
# 24814  Av. Senador Levindo Coelho, 4002 - Mangueiras,...
# 24815  R. Tiradentes, 114 - Parque Elizabeth, Ibirité...
# 24816  R. Luzia Mendes - Marilândia, Ibirité - MG, 32...
# 24817  R. Amazonas - Vila Universal, Betim - MG, 3267...
#
#                               borough  ... booking_appointment_link menu_link  \
# 0                          Santa Cruz  ...                      NaN       NaN
# 1                          Santa Cruz  ...                      NaN       NaN
# 2                          Santa Cruz  ...                      NaN       NaN
# 3                     Duque de Caxias  ...                      NaN       NaN
# 4      Dom I. Jardim Piemonte / Norte  ...                      NaN       NaN
# ...                               ...  ...                      ...       ...
# 24813       Vila Pinho Vale do Jatobá  ...                      NaN       NaN
# 24814                      Mangueiras  ...                      NaN       NaN
# 24815                Parque Elizabeth  ...                      NaN       NaN
# 24816                      Marilândia  ...                      NaN       NaN
# 24817                  Vila Universal  ...                      NaN       NaN
#
#       order_links location_link                     place_id  \
# 0             NaN           NaN  ChIJec8WgYPBpgARYsNFb8U0QfU
# 1             NaN           NaN  ChIJNWFiv6vBpgARDrZK1ghhCs8
# 2             NaN           NaN  ChIJ-bUA6hnBpgARuDZjecjjKik
# 3             NaN           NaN  ChIJFT5A3JLBpgAR-X5jqB2N9uo
# 4             NaN           NaN  ChIJY9RgbcW_pgAR9Uo0ePpzMRk
# ...           ...           ...                          ...
# 24813         NaN           NaN  ChIJu6R8NBC_pgARAfXvAhMxQoc
# 24814         NaN           NaN  ChIJwfOxR2-_pgARF_b2pse0eAA
# 24815         NaN           NaN  ChIJ51XnAsG-pgARsIzBAEVEb6k
# 24816         NaN           NaN  ChIJvVhBVPe_pgARHCRrpiTj_e0
# 24817         NaN           NaN  ChIJS8QZIKbqpgARQa1assKhISk
#
#                                  google_id                   cid  \
# 0      0xa6c1838116cf79:0xf54134c56f45c362  17672464435358581602
# 1      0xa6c1abbf626135:0xcf0a6108d64ab60e  14918843406201042446
# 2      0xa6c119ea00b5f9:0x292ae3c8796336b8   2966433754746402488
# 3      0xa6c192dc403e15:0xeaf68d1da8637ef9  16930875007664619257
# 4      0xa6bfc56d60d463:0x193173fa78344af5   1815359644402731765
# ...                                    ...                   ...
# 24813  0xa6bf10347ca4bb:0x8742311302eff501   9746406501306594561
# 24814    0xa6bf6f47b1f3c1:0x78b4c7a6f6f617     33975766797973015
# 24815  0xa6bec102e755e7:0xa96f444500c18cb0  12209052177980820656
# 24816  0xa6bff7544158bd:0xedfde324a66b241c  17149112702647084060
# 24817  0xa6eaa62019c44b:0x2921a1c2b25aad41   2963827887374511425
#
#                  reviews_id  located_google_id                  category_y
# 0       -774279638350970014                NaN          Oficinas Mecânicas
# 1      -3527900667508509170                NaN          Oficinas Mecânicas
# 2       2966433754746402488                NaN          Oficinas Mecânicas
# 3      -1515869066044932359                NaN          Oficinas Mecânicas
# 4       1815359644402731765                NaN          Oficinas Mecânicas
# ...                     ...                ...                         ...
# 24813  -8700337572402957055                NaN  Restaurantes e Lanchonetes
# 24814                  None                NaN  Restaurantes e Lanchonetes
# 24815                  None                NaN  Restaurantes e Lanchonetes
# 24816  -1297631371062467556                NaN  Restaurantes e Lanchonetes
# 24817   2963827887374511425                NaN  Restaurantes e Lanchonetes
#
# [24818 rows x 61 columns]

# %%
# for idx, row in df.iterrows():
#     print(row['category'])

# %%
# Por merge

df = merge(df, gloss_tipos, how='left', left_on='type', right_index=True)

# Capturar somente incompatíveis

# df = merge(df, gloss_tipos, how='outer', left_on='type', right_index=True, indicator=True)
# left_only = df.loc[df['_merge'] == "left_only"]
# left_only = left_only.loc[notnull(left_only['type'])]
# left_only = left_only.drop_duplicates(['type'], keep='first')
# left_only = left_only['type']

# %%
left_only
# Out:
# 13.0                     Oficina de conserto de câmeras
# 95.0                    Serviço de empresa para empresa
# 206.0                Manutenção de Máquinas Industriais
# 499.0                  Secretaria Municipal de Esportes
# 515.0                   Oficina de conserto de tratores
#                                ...
# 11149.0                             Serviços domésticos
# 11227.0                                           Coral
# 11321.0          Loja de mobílias para lojas e mercados
# 11340.0                                        Calçadão
# 11365.0    Loja de equipamentos para decoração de bolos
# Name: type, Length: 122, dtype: object

# %%
categories = DataFrame({'df_cat' : df['category_x'], 'glossary_cat' : df['category_y']})

# %%
categories.apply(lambda row: row['df_cat'] if isnull(row['glossary_cat']) else row['glossary_cat'], axis=1).head(30)
# Out:
# 0                 Oficinas Mecânicas
# 1                 Oficinas Mecânicas
# 2                 Oficinas Mecânicas
# 3                 Oficinas Mecânicas
# 4                 Oficinas Mecânicas
# 5                 Oficinas Mecânicas
# 6                 Oficinas Mecânicas
# 7                 Oficinas Mecânicas
# 8                 Oficinas Mecânicas
# 9                 Oficinas Mecânicas
# 10                Oficinas Mecânicas
# 11                Oficinas Mecânicas
# 12                Oficinas Mecânicas
# 13    Oficina de conserto de câmeras
# 14                Oficinas Mecânicas
# 15                Oficinas Mecânicas
# 16                Oficinas Mecânicas
# 17                Oficinas Mecânicas
# 18                Oficinas Mecânicas
# 19                Oficinas Mecânicas
# 20                Oficinas Mecânicas
# 21                Oficinas Mecânicas
# 22                Oficinas Mecânicas
# 23                Oficinas Mecânicas
# 24                Oficinas Mecânicas
# 25                Oficinas Mecânicas
# 26                Oficinas Mecânicas
# 27                Oficinas Mecânicas
# 28                Oficinas Mecânicas
# 29                Oficinas Mecânicas
# dtype: object

# %%
df['category'] = df.apply(lambda row: row['category'] if isnull(row['category_y']) else row['category_y'], axis=1)

# %%
df.head(30)
# Out:
#     Unnamed: 0                                              query  \
# 0            0  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 1            1  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 2            2  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 3            3  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 4            4  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 5            5  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 6            6  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 7            7  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 8            8  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 9            9  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 10          10  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 11          11  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 12          12  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 13          13  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 14          14  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 15          15  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 16          16  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 17          17  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 18          18  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 19          19  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 20          20  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 21          21  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 22          22  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 23          23  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 24          24  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 25          25  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 26          26  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 27          27  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 28          28  Borracharia, Jardim Santa Cruz, Betim, Minas G...
# 29          29  Borracharia, Jardim Santa Cruz, Betim, Minas G...
#
#                                             name  \
# 0                     Pneus e borracharia amorim
# 1          Borracharia Pitstop (serviço e geral)
# 2                           Borracharia Salmo 27
# 3                                 Borracharia Th
# 4                          Borracharia Vida Nova
# 5                                    Borracharia
# 6                       BORRACHARIA SAMUKA BETIM
# 7                                    Borracharia
# 8                        Sos Socorro Borracharia
# 9                           Borracharia do Félix
# 10  Borracharia Borracheiro Troca de Pneu Furado
# 11                        Borracharia MFernandes
# 12                                   Borracharia
# 13                             BORRACHARIA 4VIAS
# 14                     Borracharia Do Zangado Bs
# 15                          Borracharia Stop Car
# 16                          Borracharia Carlinho
# 17                           Borracharia silvano
# 18                       BORRACHARIA SANTA MARIA
# 19                                Borracharia Jl
# 20        Borracharia & Alinhamento Das Américas
# 21             PAULINHO BORRACHARIA & ACESSÓRIOS
# 22                        Borracharia th Niterói
# 23                             Borracharia lúcio
# 24                          Borracharia 2 Irmãos
# 25                         Borracharia Art Pneus
# 26                        Borracharia Boas Novas
# 27      PAULINHO BORRACHARIA & ACESSÓRIOS Loja 2
# 28                        Borracharia Badú Pneus
# 29                          Borracharia do Negão
#
#                                                  site  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  https://borrachariadozangado.negocio.site/?utm...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  https://paulinho-borracharia-acessorios.negoci...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                   type  \
# 0   Fornecedor de produtos de borracha
# 1                     Comércio de Pneu
# 2                    Loja de autopeças
# 3                     Comércio de Pneu
# 4                 Loja de pneus usados
# 5                    Loja de autopeças
# 6                 Loja de pneus usados
# 7                    Loja de autopeças
# 8                          Borracharia
# 9   Fornecedor de produtos de borracha
# 10                         Borracharia
# 11                    Comércio de Pneu
# 12                   Loja de autopeças
# 13      Oficina de conserto de câmeras
# 14                         Borracharia
# 15                         Borracharia
# 16                         Borracharia
# 17                         Borracharia
# 18                         Borracharia
# 19                   Loja de autopeças
# 20                Loja de pneus usados
# 21                    Comércio de Pneu
# 22                Loja de pneus usados
# 23                         Borracharia
# 24                   Loja de autopeças
# 25                    Comércio de Pneu
# 26                         Borracharia
# 27                    Comércio de Pneu
# 28                   Loja de autopeças
# 29                         Borracharia
#
#                                              subtypes  \
# 0                  Fornecedor de produtos de borracha
# 1                                    Comércio de Pneu
# 2                                   Loja de autopeças
# 3                                    Comércio de Pneu
# 4                                Loja de pneus usados
# 5                                   Loja de autopeças
# 6   Loja de pneus usados, Loja de peças para motoc...
# 7                                   Loja de autopeças
# 8                                         Borracharia
# 9                  Fornecedor de produtos de borracha
# 10                                        Borracharia
# 11  Comércio de Pneu, Loja de suspensões de automó...
# 12                                  Loja de autopeças
# 13                     Oficina de conserto de câmeras
# 14                                        Borracharia
# 15                                        Borracharia
# 16                                        Borracharia
# 17                                        Borracharia
# 18                                        Borracharia
# 19                                  Loja de autopeças
# 20                               Loja de pneus usados
# 21                                   Comércio de Pneu
# 22                               Loja de pneus usados
# 23                                        Borracharia
# 24                                  Loja de autopeças
# 25                                   Comércio de Pneu
# 26                                        Borracharia
# 27                                   Comércio de Pneu
# 28                                  Loja de autopeças
# 29                                        Borracharia
#
#                           category              phone  \
# 0               Oficinas Mecânicas  +55 31 99262-7295
# 1               Oficinas Mecânicas                NaN
# 2               Oficinas Mecânicas                NaN
# 3               Oficinas Mecânicas                NaN
# 4               Oficinas Mecânicas   +55 31 3597-0515
# 5               Oficinas Mecânicas                NaN
# 6               Oficinas Mecânicas  +55 31 97558-7629
# 7               Oficinas Mecânicas                NaN
# 8               Oficinas Mecânicas  +55 31 99777-8566
# 9               Oficinas Mecânicas                NaN
# 10              Oficinas Mecânicas                NaN
# 11              Oficinas Mecânicas  +55 31 99118-5620
# 12              Oficinas Mecânicas                NaN
# 13  Oficina de conserto de câmeras  +55 31 99227-4905
# 14              Oficinas Mecânicas  +55 31 99837-1271
# 15              Oficinas Mecânicas  +55 31 99777-8566
# 16              Oficinas Mecânicas  +55 31 99821-2930
# 17              Oficinas Mecânicas  +55 31 98847-5280
# 18              Oficinas Mecânicas   +55 31 3046-7786
# 19              Oficinas Mecânicas                NaN
# 20              Oficinas Mecânicas   +55 31 3023-4457
# 21              Oficinas Mecânicas  +55 31 97366-7354
# 22              Oficinas Mecânicas  +55 31 98956-9407
# 23              Oficinas Mecânicas  +55 31 98626-0377
# 24              Oficinas Mecânicas                NaN
# 25              Oficinas Mecânicas                NaN
# 26              Oficinas Mecânicas  +55 31 99753-8721
# 27              Oficinas Mecânicas  +55 31 97366-7354
# 28              Oficinas Mecânicas                NaN
# 29              Oficinas Mecânicas                NaN
#
#                                          full_address  \
# 0   Rod. Br 381 Fernao Dias, 153 - Santa Cruz, Bet...
# 1                   Santa Cruz, Betim - MG, 32667-380
# 2   Av. Rio Madeira, 2082 - Santa Cruz, Betim - MG...
# 3   Av. das Palmeiras, 341 - Duque de Caxias, Beti...
# 4   R. Gracyra Resse de Gouvêia, 998 - Dom I. Jard...
# 5   Av. Juiz Marco Túlio Isaac - Parque das Indust...
# 6   R. Guidoval, 34 - Industrial São Luiz, Betim -...
# 7   R. Vinte e Quatro, 39 - Cruzeiro do Sul, Betim...
# 8   Av. Arthur Trindade, 1645 - Jardim das Alteros...
# 9   R. Beirute, N°830 - Duque de Caxias, Betim - M...
# 10  Rod. Fernão Dias, 5000a - Distrito Industrial ...
# 11  R. São Silvério, 1175 - Campos Elísios, Betim ...
# 12  R. Saudade - Jardim das Alterosas - 2ª Seção, ...
# 13  R. das Falcatas, 730 - Jardim das Alterosas - ...
# 14  R. Jovelino Gregório da Silva, 556 - Kennedy, ...
# 15  Av. Arthur Trindade, 1645 - Loja 7 - Jardim da...
# 16  Rua Três - Contagem - Kennedy, Betim - MG, 321...
# 17  R. Santo Agostinho, 441 - Parque das Acácias, ...
# 18  R. Cel. Salvador Fernandes, 429 - Bandeirantes...
# 19  Av. Juiz Marco Túlio Isaac - Laranjeiras, Beti...
# 20  R. dos Estados - Filadélfia, Betim - MG, 32670...
# 21  Avenida Coletora, Av. Arthur Trindade, 179 - J...
# 22  R. Diamantina, 61 - Niterói, Betim - MG, 32672...
# 23  R. Borboletas, 277 - Jardim das Alterosas - 2ª...
# 24  Av. Belo Horizonte, 397 - Cruzeiro do Sul, Bet...
# 25  Av. Juiz Marco Túlio Isaac - Parque das Indust...
# 26  Av. Tapajós, 1183 A - São Cristovao, Betim - M...
# 27  Av. Juiz Marco Túlio Isaac, 2583 - Parque das ...
# 28  R. Jonas Belizário, 884 - Laranjeiras, Betim -...
# 29  R. Tiradentes, 175 - Parque das Industrias, Be...
#
#                                  borough  ... booking_appointment_link  \
# 0                             Santa Cruz  ...                      NaN
# 1                             Santa Cruz  ...                      NaN
# 2                             Santa Cruz  ...                      NaN
# 3                        Duque de Caxias  ...                      NaN
# 4         Dom I. Jardim Piemonte / Norte  ...                      NaN
# 5                  Parque das Industrias  ...                      NaN
# 6                    Industrial São Luiz  ...                      NaN
# 7                        Cruzeiro do Sul  ...                      NaN
# 8        Jardim das Alterosas - 2ª Seção  ...                      NaN
# 9                        Duque de Caxias  ...                      NaN
# 10  Distrito Industrial Paulo Camilo Sul  ...                      NaN
# 11                        Campos Elísios  ...                      NaN
# 12       Jardim das Alterosas - 2ª Seção  ...                      NaN
# 13       Jardim das Alterosas - 1A Secao  ...                      NaN
# 14                               Kennedy  ...                      NaN
# 15       Jardim das Alterosas - 2ª Seção  ...                      NaN
# 16                               Kennedy  ...                      NaN
# 17                    Parque das Acácias  ...                      NaN
# 18                          Bandeirantes  ...                      NaN
# 19                           Laranjeiras  ...                      NaN
# 20                            Filadélfia  ...                      NaN
# 21       Jardim das Alterosas - 2ª Seção  ...                      NaN
# 22                               Niterói  ...                      NaN
# 23       Jardim das Alterosas - 2ª Seção  ...                      NaN
# 24                       Cruzeiro do Sul  ...                      NaN
# 25                 Parque das Industrias  ...                      NaN
# 26                         São Cristovao  ...                      NaN
# 27                 Parque das Industrias  ...                      NaN
# 28                           Laranjeiras  ...                      NaN
# 29                 Parque das Industrias  ...                      NaN
#
#    menu_link order_links location_link                     place_id  \
# 0        NaN         NaN           NaN  ChIJec8WgYPBpgARYsNFb8U0QfU
# 1        NaN         NaN           NaN  ChIJNWFiv6vBpgARDrZK1ghhCs8
# 2        NaN         NaN           NaN  ChIJ-bUA6hnBpgARuDZjecjjKik
# 3        NaN         NaN           NaN  ChIJFT5A3JLBpgAR-X5jqB2N9uo
# 4        NaN         NaN           NaN  ChIJY9RgbcW_pgAR9Uo0ePpzMRk
# 5        NaN         NaN           NaN  ChIJ-8z1CbLBpgARmYcI33OttIo
# 6        NaN         NaN           NaN  ChIJO8BX5VfBpgARABdVgdazce8
# 7        NaN         NaN           NaN  ChIJ2-1OGvTBpgARbx3zP5Xi6Xo
# 8        NaN         NaN           NaN  ChIJP5gigC7BpgARGQncRHsUiOo
# 9        NaN         NaN           NaN  ChIJ5zy_a7_BpgARJaPuM5bF8ZY
# 10       NaN         NaN           NaN  ChIJo9e_GK_BpgARpRDBTKyWeKQ
# 11       NaN         NaN           NaN  ChIJYRUY0D3BpgAR0acv2fypl0w
# 12       NaN         NaN           NaN  ChIJyXMU25HBpgAR-E_5A_GDrhk
# 13       NaN         NaN           NaN  ChIJfScjwoTBpgARiDExW98hyfQ
# 14       NaN         NaN           NaN  ChIJP-DDSkfBpgAR_J5nQoTcfuY
# 15       NaN         NaN           NaN  ChIJBywAY_vBpgARCEZmO5U8N4o
# 16       NaN         NaN           NaN  ChIJZyMoxXaVpgARXTf2k5A7xTo
# 17       NaN         NaN           NaN  ChIJSw-QykjBpgARZxXVKS5rdNk
# 18       NaN         NaN           NaN  ChIJ67pUfGK_pgAR8JULVdoTqsQ
# 19       NaN         NaN           NaN  ChIJPfUY6knApgARYONiq7IgK68
# 20       NaN         NaN           NaN  ChIJPaoFp5TDpgARR9jZNLa8jcY
# 21       NaN         NaN           NaN  ChIJa1jtKgDBpgARaCyqmsnx3pw
# 22       NaN         NaN           NaN  ChIJMff6YQzDpgAREg-Kx4k2Tlc
# 23       NaN         NaN           NaN  ChIJzaiwBR7BpgARBjMvtddwwOI
# 24       NaN         NaN           NaN  ChIJN_KDKPLBpgARpc-qOkU1jKQ
# 25       NaN         NaN           NaN  ChIJ7SX0W4XBpgARS3FoLyKSXek
# 26       NaN         NaN           NaN  ChIJwRIFTVrBpgARHD7DBmkNeO0
# 27       NaN         NaN           NaN  ChIJyXxdVF7BpgARZGedD5sM6Uc
# 28       NaN         NaN           NaN  ChIJ1UePCTbApgAR9_yVbnL2kWk
# 29       NaN         NaN           NaN  ChIJCQvuDSjDpgARH2yURJQ22bc
#
#                               google_id                   cid  \
# 0   0xa6c1838116cf79:0xf54134c56f45c362  17672464435358581602
# 1   0xa6c1abbf626135:0xcf0a6108d64ab60e  14918843406201042446
# 2   0xa6c119ea00b5f9:0x292ae3c8796336b8   2966433754746402488
# 3   0xa6c192dc403e15:0xeaf68d1da8637ef9  16930875007664619257
# 4   0xa6bfc56d60d463:0x193173fa78344af5   1815359644402731765
# 5   0xa6c1b209f5ccfb:0x8ab4ad73df088799   9994804186216695705
# 6   0xa6c157e557c03b:0xef71b3d681551700  17253769381307291392
# 7   0xa6c1f41a4eeddb:0x7ae9e2953ff31d6f   8856859272851692911
# 8   0xa6c12e8022983f:0xea88147b44dc0919  16899780121376590105
# 9   0xa6c1bf6bbf3ce7:0x96f1c59633eea325  10876691823983502117
# 10  0xa6c1af18bfd7a3:0xa47896ac4cc110a5  11851388086191722661
# 11  0xa6c13dd0181561:0x4c97a9fcd92fa7d1   5519066771806463953
# 12  0xa6c191db1473c9:0x19ae83f103f94ff8   1850561568072880120
# 13  0xa6c184c223277d:0xf4c921df5b313188  17638666658764632456
# 14  0xa6c1474ac3e03f:0xe67edc8442679efc  16608954936396848892
# 15  0xa6c1fb63002c07:0x8a373c953b664608   9959495712597493256
# 16  0xa69576c5282367:0x3ac53b9093f6375d   4234856516755535709
# 17  0xa6c148ca900f4b:0xd9746b2e29d51567  15669266849543296359
# 18  0xa6bf627c54baeb:0xc4aa13da550b95f0  14171161005925307888
# 19  0xa6c049ea18f53d:0xaf2b20b2ab62e360  12622218332387599200
# 20  0xa6c394a705aa3d:0xc68dbcb634d9d847  14307299081982695495
# 21  0xa6c1002aed586b:0x9cdef1c99aaa2c68  11303737962932087912
# 22  0xa6c30c61faf731:0x574e3689c78a0f12   6291025694869294866
# 23  0xa6c11e05b0a8cd:0xe2c070d7b52f3306  16339183519860208390
# 24  0xa6c1f22883f237:0xa48c35453aaacfa5  11856910490412961701
# 25  0xa6c1855bf425ed:0xe95d92222f68714b  16815757259193217355
# 26  0xa6c15a4d0512c1:0xed780d6906c33e1c  17111441528930385436
# 27  0xa6c15e545d7cc9:0x47e90c9b0f9d6764   5181686706387904356
# 28  0xa6c036098f47d5:0x6991f6726e95fcf7   7607132216947506423
# 29  0xa6c3280dee0b09:0xb7d9369444946c1f  13247679789320662047
#
#               reviews_id  located_google_id          category_y
# 0    -774279638350970014                NaN  Oficinas Mecânicas
# 1   -3527900667508509170                NaN  Oficinas Mecânicas
# 2    2966433754746402488                NaN  Oficinas Mecânicas
# 3   -1515869066044932359                NaN  Oficinas Mecânicas
# 4    1815359644402731765                NaN  Oficinas Mecânicas
# 5   -8451939887492855911                NaN  Oficinas Mecânicas
# 6   -1192974692402260224                NaN  Oficinas Mecânicas
# 7                   None                NaN  Oficinas Mecânicas
# 8                   None                NaN  Oficinas Mecânicas
# 9                   None                NaN  Oficinas Mecânicas
# 10                  None                NaN  Oficinas Mecânicas
# 11   5519066771806463953                NaN  Oficinas Mecânicas
# 12                  None                NaN  Oficinas Mecânicas
# 13   -808077414944919160                NaN                 NaN
# 14  -1837789137312702724                NaN  Oficinas Mecânicas
# 15  -8487248361112058360                NaN  Oficinas Mecânicas
# 16                  None                NaN  Oficinas Mecânicas
# 17  -2777477224166255257                NaN  Oficinas Mecânicas
# 18  -4275583067784243728                NaN  Oficinas Mecânicas
# 19                  None                NaN  Oficinas Mecânicas
# 20  -4139444991726856121                NaN  Oficinas Mecânicas
# 21  -7143006110777463704                NaN  Oficinas Mecânicas
# 22   6291025694869294866                NaN  Oficinas Mecânicas
# 23                  None                NaN  Oficinas Mecânicas
# 24                  None                NaN  Oficinas Mecânicas
# 25                  None                NaN  Oficinas Mecânicas
# 26  -1335302544779166180                NaN  Oficinas Mecânicas
# 27   5181686706387904356                NaN  Oficinas Mecânicas
# 28                  None                NaN  Oficinas Mecânicas
# 29  -5199064284388889569                NaN  Oficinas Mecânicas
#
# [30 rows x 61 columns]

# %%
df.rename(columns={'category_x' : 'category'}, inplace=True)

# %%
df['category'] = df['category_y']

# %%
del df['category_y']

# %%
df = df.loc[isnull(df['name'])]

# %%
left_only.to_csv('gloss_incompatible_betim-mg.csv')

# %%
# Análise
saopaulosp = read_excel("sem_mod/SP - São Paulo/20230518121045110b_extracao03_saopaulo-sp.xlsx")

# %%
saopaulosp
# Out:
#                                                     query  \
# 0       Loja de moda, José Bonifácio, Sâo Paulo, São P...
# 1       Loja de moda, José Bonifácio, Sâo Paulo, São P...
# 2       Loja de moda, José Bonifácio, Sâo Paulo, São P...
# 3       Loja de moda, José Bonifácio, Sâo Paulo, São P...
# 4       Loja de moda, José Bonifácio, Sâo Paulo, São P...
# ...                                                   ...
# 114059   Advogado, Itaquera, Sâo Paulo, São Paulo, Brasil
# 114060  Advogado, Jardim Iguatemi, Sâo Paulo, São Paul...
# 114061  Advogado, Jardim Iguatemi, Sâo Paulo, São Paul...
# 114062  Advogado, Jardim Iguatemi, Sâo Paulo, São Paul...
# 114063  Advogado, Jardim Iguatemi, Sâo Paulo, São Paul...
#
#                                   name  \
# 0                              Moda Ka
# 1                        Maroleo modas
# 2       Touchic Modas - José Bonifácio
# 3        RK Modas Feminina e Masculina
# 4       À Dondóquinha - José Bonifácio
# ...                                ...
# 114059            C. Miranda Advocacia
# 114060            Almeida & Associados
# 114061               Alencar Advocacia
# 114062  M & M - Sociedade de Advogados
# 114063                 Advocacia Bueno
#
#                                                      site  \
# 0       https://www.facebook.com/P%C3%A1gina-Moda-Ka-J...
# 1                                                     NaN
# 2                                                     NaN
# 3       https://instagram.com/keurifernandajb?igshid=Y...
# 4                                                     NaN
# ...                                                   ...
# 114059                                                NaN
# 114060                                                NaN
# 114061                http://www.alencaradvogados.com.br/
# 114062                                                NaN
# 114063                                                NaN
#
#                                       type  \
# 0                            Loja de Roupa
# 1                            Loja de Roupa
# 2                            Loja de Roupa
# 3                    Loja de moda feminina
# 4                            Loja de Roupa
# ...                                    ...
# 114059                   Advogado criminal
# 114060                Empresa de advocacia
# 114061  Advogado especialista em divórcios
# 114062             Escritório de advocacia
# 114063             Escritório de advocacia
#
#                                           subtypes                 category  \
# 0                                    Loja de Roupa            Loja de Roupa
# 1                                    Loja de Roupa            Loja de Roupa
# 2                                    Loja de Roupa            Loja de Roupa
# 3                            Loja de moda feminina    Loja de moda feminina
# 4                                    Loja de Roupa            Loja de Roupa
# ...                                            ...                      ...
# 114059    Advogado criminal, Service establishment        Advogado criminal
# 114060                        Empresa de advocacia     Empresa de advocacia
# 114061          Advogado especialista em divórcios           Divorce lawyer
# 114062  Escritório de advocacia, Advogado criminal  Escritório de advocacia
# 114063                     Escritório de advocacia  Escritório de advocacia
#
#                     phone                                       full_address  \
# 0                     NaN  Av. Nove de Julho, 601 - Centro Histórico de S...
# 1        +55 17 3245-1876  Rua:Domingos Fernandes Alonso, 363 - Centro, J...
# 2       +55 17 99762-3567  R. São José, 335 - Centro, José Bonifácio - SP...
# 3       +55 17 99253-7382  Av. Antônio Gonçalves da Silva, 1017 - Centro,...
# 4       +55 17 99642-4457  Av. Nove de Julho, 349 - Centro, José Bonifáci...
# ...                   ...                                                ...
# 114059  +55 11 92006-7883                                                NaN
# 114060  +55 11 93772-4610  Av. Ragueb Chohfi, 4481 - Jardim Três Marias, ...
# 114061   +55 11 2767-0331  Av. Bento Guelfi, nº 1.995 - sala 2 - Jardim A...
# 114062  +55 17 99667-1162  Tv. Salassiê, 100 - Jardim da Conquista, São P...
# 114063  +55 11 94801-2512  R. Xipotó, 9 - Jardim Roseli, São Paulo - SP, ...
#
#                               borough                                street  \
# 0       Centro Histórico de São Paulo                Av. Nove de Julho, 601
# 1                              Centro    Rua:Domingos Fernandes Alonso, 363
# 2                              Centro                      R. São José, 335
# 3                              Centro  Av. Antônio Gonçalves da Silva, 1017
# 4                              Centro                Av. Nove de Julho, 349
# ...                               ...                                   ...
# 114059                           None                                   NaN
# 114060             Jardim Três Marias               Av. Ragueb Chohfi, 4481
# 114061             Jardim Alto Alegre   Av. Bento Guelfi, nº 1.995 - sala 2
# 114062            Jardim da Conquista                     Tv. Salassiê, 100
# 114063                  Jardim Roseli                          R. Xipotó, 9
#
#         ... reservation_links booking_appointment_link menu_link  order_links  \
# 0       ...               NaN                      NaN       NaN          NaN
# 1       ...               NaN                      NaN       NaN          NaN
# 2       ...               NaN                      NaN       NaN          NaN
# 3       ...               NaN                      NaN       NaN          NaN
# 4       ...               NaN                      NaN       NaN          NaN
# ...     ...               ...                      ...       ...          ...
# 114059  ...               NaN                      NaN       NaN          NaN
# 114060  ...               NaN                      NaN       NaN          NaN
# 114061  ...               NaN                      NaN       NaN          NaN
# 114062  ...               NaN                      NaN       NaN          NaN
# 114063  ...               NaN                      NaN       NaN          NaN
#
#                                             location_link  \
# 0       https://www.google.com/maps/place/Moda+Ka/@-21...
# 1       https://www.google.com/maps/place/Maroleo+moda...
# 2       https://www.google.com/maps/place/Touchic+Moda...
# 3       https://www.google.com/maps/place/RK+Modas+Fem...
# 4       https://www.google.com/maps/place/%C3%80+Dond%...
# ...                                                   ...
# 114059  https://www.google.com/maps/place/C.+Miranda+A...
# 114060  https://www.google.com/maps/place/Almeida+%26+...
# 114061  https://www.google.com/maps/place/Alencar+Advo...
# 114062  https://www.google.com/maps/place/M+%26+M+-+So...
# 114063  https://www.google.com/maps/place/Advocacia+Bu...
#
#                            place_id                              google_id  \
# 0       ChIJ5UUHf_y_vZQRwoWchzaAsqY  0x94bdbffc7f0745e5:0xa6b28036879c85c2
# 1       ChIJ9cby5-O_vZQR-p4apJIxRD8  0x94bdbfe3e7f2c6f5:0x3f443192a41a9efa
# 2       ChIJYZa2Gfi_vZQR_4kgWDAK4Fc  0x94bdbff819b69661:0x57e00a30582089ff
# 3       ChIJjzQx1D6_vZQRYkQFmqMBw94  0x94bdbf3ed431348f:0xdec301a39a054462
# 4       ChIJMfpSOlm_vZQRKfvHuIWVcao  0x94bdbf593a52fa31:0xaa719585b8c7fb29
# ...                             ...                                    ...
# 114059  ChIJrwuTak1LkCQRMrYpPpxSqe8  0x24904b4d6a930baf:0xefa9529c3e29b632
# 114060  ChIJYfJquQFmzpQRzp-lKXw8RkE  0x94ce6601b96af261:0x41463c7c29a59fce
# 114061  ChIJa-EwyClvzpQRMmAjwHkg_oY  0x94ce6f29c830e16b:0x86fe2079c0236032
# 114062  ChIJt9FdQitpzpQRU2040KbtfH0  0x94ce692b425dd1b7:0x7d7ceda6d0386d53
# 114063  ChIJHVqNxoNpzpQRJrnHk3iA7XU  0x94ce6983c68d5a1d:0x75ed807893c7b926
#
#                          cid            reviews_id located_google_id
# 0       12011804127842305474  -6434939945867246142               NaN
# 1        4558823228693978874   4558823228693978874               NaN
# 2        6332072278836152831   6332072278836152831               NaN
# 3       16051675299053913186  -2395068774655638430               NaN
# 4       12281762060379355945  -6164982013330195671               NaN
# ...                      ...                   ...               ...
# 114059  17269425077140174386                  None               NaN
# 114060   4703513364807393230   4703513364807393230               NaN
# 114061   9727247952453525554  -8719496121256026062               NaN
# 114062   9042363452566826323   9042363452566826323               NaN
# 114063   8497589327281764646                  None               NaN
#
# [114064 rows x 59 columns]

# %%
## REGISTROS COM OPERADORA

# %%
records_df = read_csv('notnull-number-operator_202305312220.csv')

# %%
records_df
# Out:
#                                 internalId  \
# 0     59b56678-a4ee-46c3-bcf0-b7b8f54193be
# 1     111406b6-f611-444a-861c-15abad205e7c
# 2     49d70d69-fe6e-4dd5-935e-1efaca8514c4
# 3     48bc8da1-f313-4cc4-94e0-4b0f260fa3ca
# 4     fd0bbb33-a70e-4d19-8560-38c5ebe48167
# ...                                    ...
# 4964  c8b7e3e2-bbb0-47cc-ab25-dafb361c3549
# 4965  469f62d1-15de-456d-b8e5-9180163734ac
# 4966  c2a5cea4-9e91-46a4-9c98-759312cae2fc
# 4967  125a6ceb-e0fb-4064-bc65-ae4fa6ddc02e
# 4968  0f54c738-8d5b-448f-910e-166162c446c9
#
#                               extractionId                     place_id  \
# 0     cba35ee2-1d91-4ed3-96dc-8c4b6ba1da47  ChIJGRLGqCiJmQARB_P7r_Iid3Y
# 1     cba35ee2-1d91-4ed3-96dc-8c4b6ba1da47  ChIJQw3Itm2FmQAR4CWaJk4gfNo
# 2     cba35ee2-1d91-4ed3-96dc-8c4b6ba1da47  ChIJ0XKtOtmDmQARsdJkJkSeVJE
# 3     cba35ee2-1d91-4ed3-96dc-8c4b6ba1da47  ChIJNW5pFeqQmQARXizD-5FbIyQ
# 4     cba35ee2-1d91-4ed3-96dc-8c4b6ba1da47  ChIJqf8o1CabmQAR3ItUkhZfU7w
# ...                                    ...                          ...
# 4964  cba35ee2-1d91-4ed3-96dc-8c4b6ba1da47  ChIJV2_9KklkmQARHt-vKOpTd1Y
# 4965  4c62e412-ebc3-4f14-b3fc-a2a8b1f8a18b  ChIJLzrUwApD65QReHeBzKp2w8U
# 4966  4c62e412-ebc3-4f14-b3fc-a2a8b1f8a18b  ChIJV2dt86lF65QRqD028gI4F5o
# 4967  4c62e412-ebc3-4f14-b3fc-a2a8b1f8a18b  ChIJBwnxgE1F65QRzC2MFktQdZ8
# 4968  4c62e412-ebc3-4f14-b3fc-a2a8b1f8a18b  ChIJ5wwNpH1D65QR4BAViOkpuRE
#
#                                   google_id                   cid  \
# 0       0x998928a8c61219:0x767722f2affbf307   8536330044434019079
# 1       0x99856db6c80d43:0xda7c204e269a25e0  15743493917407585760
# 2       0x9983d93aad72d1:0x91549e442664d2b1  10472169049082352305
# 3       0x9990ea15696e35:0x24235b91fbc32c5e   2604025692102536286
# 4       0x999b26d428ffa9:0xbc535f1692548bdc  13570294652746370012
# ...                                     ...                   ...
# 4964    0x9964492afd6f57:0x567753ea28afdf1e   6230540874660437790
# 4965  0x94eb430ac0d43a2f:0xc5c376aacc817778  14250364121877935992
# 4966  0x94eb45a9f36d6757:0x9a173802f2363da8  11103404991609978280
# 4967  0x94eb454d80f10907:0x9f75504b168c2dcc  11490178307736743372
# 4968  0x94eb437da40d0ce7:0x11b929e9881510e0   1277098052323447008
#
#                                            query_search query_keyword  \
# 0     Pousada, Várzea das Moças, Niterói, Rio de Jan...       Pousada
# 1     Mercearia, Vila Lage, Niterói, Rio de Janeiro,...     Mercearia
# 2        Pousada, Pita, Niterói, Rio de Janeiro, Brasil       Pousada
# 3     Pousada, Engenho Pequeno, Niterói, Rio de Jane...       Pousada
# 4     Mercearia, Engenho Pequeno, Niterói, Rio de Ja...     Mercearia
# ...                                                 ...           ...
# 4964  Mercearia, Vila Rosali, Niterói, Rio de Janeir...     Mercearia
# 4965      Mecânica, Aeroporto, Londrina, Paraná, Brasil      Mecânica
# 4966  Mercearia, Jardim do Lago, Londrina, Paraná, B...     Mercearia
# 4967    Mercearia, Indusville, Londrina, Paraná, Brasil     Mercearia
# 4968  Restaurantes, Jardim Caravelle, Londrina, Para...  Restaurantes
#
#      query_neighborhood query_location_city query_location_state  ...  \
# 0      Várzea das Moças             Niterói       Rio de Janeiro  ...
# 1             Vila Lage             Niterói       Rio de Janeiro  ...
# 2                  Pita             Niterói       Rio de Janeiro  ...
# 3       Engenho Pequeno             Niterói       Rio de Janeiro  ...
# 4       Engenho Pequeno             Niterói       Rio de Janeiro  ...
# ...                 ...                 ...                  ...  ...
# 4964        Vila Rosali             Niterói       Rio de Janeiro  ...
# 4965          Aeroporto            Londrina               Paraná  ...
# 4966     Jardim do Lago            Londrina               Paraná  ...
# 4967         Indusville            Londrina               Paraná  ...
# 4968   Jardim Caravelle            Londrina               Paraná  ...
#
#                      owner_title phone_ddi phone_ddd phone_number  \
# 0        Pousada Cabana da Praia        55       800          878
# 1               Assaí Atacadista        55       800          773
# 2                  Pão de Açúcar        55       800          779
# 3                 Xandico APT 01        44      7415       826961
# 4              Sacolão do Daniel        55        21     78345396
# ...                          ...       ...       ...          ...
# 4964       Hortifruti da Fartura        55        24     26626455
# 4965  Localiza Aluguel de Carros        55       800          979
# 4966                Shell Select        55       800          728
# 4967                Shell Select        55       800          728
# 4968                 Macarrão 43        55        43     31423051
#
#      phoneOperator_operatorCode phoneOperator_operatorName  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 4964                        NaN                        NaN
# 4965                        NaN                        NaN
# 4966                        NaN                        NaN
# 4967                        NaN                        NaN
# 4968                        NaN                        NaN
#
#      phoneOperator_operatorMigrated              firstSyncAt  \
# 0                               NaN  2023-05-29 15:12:06.294
# 1                               NaN  2023-05-29 15:15:35.803
# 2                               NaN  2023-05-29 15:12:07.245
# 3                               NaN  2023-05-29 15:12:08.841
# 4                               NaN  2023-05-29 15:15:36.113
# ...                             ...                      ...
# 4964                            NaN  2023-05-29 15:15:35.317
# 4965                            NaN  2023-05-29 14:56:04.308
# 4966                            NaN  2023-05-29 14:56:14.332
# 4967                            NaN  2023-05-29 14:56:18.236
# 4968                            NaN  2023-05-29 14:56:20.822
#
#                  updateSyncAt internalTag
# 0     2023-05-29 15:12:06.294  extracao03
# 1     2023-05-29 15:15:35.803  extracao03
# 2     2023-05-29 15:12:07.245  extracao03
# 3     2023-05-29 15:12:08.841  extracao03
# 4     2023-05-29 15:15:36.113  extracao03
# ...                       ...         ...
# 4964  2023-05-29 15:15:35.317  extracao03
# 4965  2023-05-29 14:56:04.308  extracao03
# 4966  2023-05-29 14:56:14.332  extracao03
# 4967  2023-05-29 14:56:18.236  extracao03
# 4968  2023-05-29 14:56:20.822  extracao03
#
# [4969 rows x 50 columns]
